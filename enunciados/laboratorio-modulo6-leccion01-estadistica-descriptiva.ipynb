# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>
#
#
# # Laboratorio Estadistica Descriptiva
#
# ⚠️ Siempre que puedas usa graficas para apoyar tu interpretacion

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np  
import pandas as pd 


# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns


# librerias para estadisticas 
# ------------------------------------------------------------------------------

import statistics as st 
from scipy import stats  
from scipy.stats import skew,kurtosis # libreria para asimetria y curtosis

# %% [markdown]
# #### Ejercicio 1:
#
# 1.  Dados los siguientes datos: [15, 21, 25, 32, 35, 45, 50, 50, 55, 60]. Crea una funcion que calcule la media, mediana y moda.

# %%
lista1 = [15, 21, 25, 32, 35, 45, 50, 50, 55, 60]

def estadisticos(lista):
    df = pd.DataFrame(lista)
    print(f"Media: {df.mean()[0]}")
    print(f"Mediana: {df.median()[0]}")
    print(f"Moda: {df.mode()[0]}")

#media, mediana, moda = mean(lista1)

estadisticos(lista1)
# Out:
# Media: 38.8
# Mediana: 40.0
# Moda: 0    50
# Name: 0, dtype: int64

# %% [markdown]
# 2.	Interpretación de la media: ¿Qué sucede si un valor extremo, como 100, se agrega al conjunto de datos anterior? ¿Cómo cambia la media? Explica por qué sucede esto.

# %%
# La media aumentaría mucho, y ya no sería representativa del conjunto de datos. Sería entonces necesario usar la mediana, que es el valor que se encuentre en la mitad del conjunto.

# %% [markdown]
# #### Ejercicio 2:
# 1. **Cálculo de la varianza y desviación estándar**: Usando los mismos datos de arriba, calcula la **varianza** y la **desviación estándar**.

# %%
df = pd.DataFrame(lista1)

print(f"La desviación estándar es {round(df.var()[0],2)}")
print(f"La desviación estándar es {round(df.std()[0],2)}")
# Out:
# La desviación estándar es 237.29
# La desviación estándar es 15.4

# %% [markdown]
# 2. **Comparación de dispersión**: Dado otro conjunto de datos: `[18, 19, 20, 22, 24, 25, 27, 30]`, compara la **dispersión** de este grupo con el conjunto de datos anterior (del Ejercicio 1) calculando la **desviación estándar** de ambos. ¿Qué conjunto tiene mayor dispersión?

# %%
lista2 = [18, 19, 20, 22, 24, 25, 27, 30]
df2 = pd.DataFrame(lista2)

print(f"La desviación estándar de la lista 1 es {round(df.var()[0],2)}")
print(f"La desviación estándar de la lista 2 es {round(df2.var()[0],2)}")
# Out:
# La desviación estándar de la lista 1 es 237.29
# La desviación estándar de la lista 2 es 17.27

# %%
fig, axes = plt.subplots(2, 1)

sns.scatterplot(data=df, ax=axes[0])
sns.scatterplot(data=df2, ax=axes[1])
# Out:
# <Axes: >

# %%
# Hay mayor dispersión en el primer conjunto. Los datos se alejan más unos de otros.

# %% [markdown]
# #### Ejercicio 3:
#
# 1. Usa la función correspondiente en Python para calcular la **asimetría** del conjunto de datos: `[10, 20, 20, 20, 25, 30, 35, 40]`.

# %%
lista3 = [10, 20, 20, 20, 25, 30, 35, 40]
stats.skew(lista3)
# Out:
# np.float64(0.1280077375904375)

# %% [markdown]
# 2. Interpreta el resultado: ¿El conjunto es simétrico, sesgado a la izquierda o a la derecha?

# %%
# Un valor positivo indica que la cola está a la derecha de la distribución, extendiéndose a valores más positivos.

sns.histplot(lista3, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #### Ejercicio 4:
#
# 1. Calcula la **curtosis** para el conjunto de datos: `[5, 5, 5, 20, 25, 30, 30, 50]`.

# %%
lista4 = [5, 5, 5, 20, 25, 30, 30, 50]
pd.DataFrame(lista4).kurt()
# Out:
# 0   -0.145142
# dtype: float64

# %% [markdown]
# 2. ¿El conjunto tiene una curtosis positiva, negativa o es mesocúrtico? Explica qué implica esto sobre la forma de la distribución.

# %%
# Es negativa, significa que tenemos una forma más llana.

sns.histplot(lista4)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# #### Ejercicio 5: Caso practico.
#
#
# Imagina que una empresa está evaluando el rendimiento de sus empleados para entender la relación entre el tiempo que dedican a su trabajo y el éxito que tienen en términos de ventas. La empresa recopila datos durante un mes, midiendo cuántas **horas trabajó** cada empleado y cuántas **ventas realizaron**. Estos datosa se encuentran en el archivo `rendimiento.csv`
#
# **Horas trabajadas**:
#    - Se midieron las horas trabajadas por un grupo de empleados. En general, la mayoría de los empleados trabajan entre 40 y 60 horas a la semana, con algunos empleados trabajando un poco menos o más.
#
#
# **Ventas realizadas**:
#    - A cada empleado también se le hizo un seguimiento de cuántas ventas realizó. Aunque las ventas están influenciadas por las horas trabajadas, hay cierta **variabilidad**: algunos empleados pueden ser más productivos y vender más en menos tiempo, mientras que otros necesitan trabajar más para alcanzar los mismos resultados.
#
#
# Resuelve los siguientes puntos:
#
#
#
# 1. **Cálculo de la media, mediana y moda**:
#    - Calcula la **media**, **mediana** y **moda** de las columnas **Horas Trabajadas** y **Ventas Realizadas**.
#    - Explica qué información proporciona cada medida en este contexto. Justifica tus conclusiones con representación de graficas.

# %%
df_rendimiento = pd.read_csv("../datos/rendimiento.csv")
df_rendimiento
# Out:
#      ID  Horas Trabajadas  Ventas Realizadas
# 0     1         54.967142               48.0
# 1     2         48.617357               47.0
# 2     3         56.476885               55.0
# 3     4         65.230299               61.0
# 4     5         47.658466               47.0
# ..  ...               ...                ...
# 95   96         35.364851               37.0
# 96   97         52.961203               49.0
# 97   98         52.610553               53.0
# 98   99         50.051135               50.0
# 99  100         47.654129               42.0
#
# [100 rows x 3 columns]

# %% [markdown]
# 2. **Comparación de medidas de centralización**:
#    - ¿Cómo se diferencian la media y la mediana para los datos de **Ventas Realizadas**? ¿Qué indica esta diferencia sobre la distribución de las ventas?

# %%
print(f"La media de ventas es {df_rendimiento['Ventas Realizadas'].mean()}")
print(f"La mediana de ventas es {df_rendimiento['Ventas Realizadas'].median()}")

# Son muy similares, quiere decir que los datos están poco dispersos y que la media es representativa del conjunto.
# Out:
# La media de ventas es 49.12
# La mediana de ventas es 48.0

# %% [markdown]
# 3. **Cálculo de la varianza y desviación estándar**:
#    - Calcula la **varianza** y la **desviación estándar** para las columnas **Horas Trabajadas** y **Ventas Realizadas**.
#    - ¿Qué conjunto de datos es más disperso? Explica el significado de la dispersión en este caso. Justifica tus conclusiones con representación de graficas.

# %%
print(f"La varianza de ventas es {round(df_rendimiento['Ventas Realizadas'].var(),2)}")
print(f"La STD de ventas es {round(df_rendimiento['Ventas Realizadas'].std(),2)}")
print(f"La varianza de horas es {round(df_rendimiento['Horas Trabajadas'].var(),2)}")
print(f"La STD de horas es {round(df_rendimiento['Horas Trabajadas'].std(),2)}")
# Out:
# La varianza de ventas es 93.06
# La STD de ventas es 9.65
# La varianza de horas es 82.48
# La STD de horas es 9.08

# %%
fig, axes = plt.subplots(2, 1)

sns.violinplot(data=df_rendimiento['Ventas Realizadas'], ax=axes[0])
sns.violinplot(data=df_rendimiento['Horas Trabajadas'], ax=axes[1])
# Out:
# <Axes: ylabel='Horas Trabajadas'>

# %% [markdown]
# 4. **Rango y rango intercuartílico**:
#    - Calcula el **rango** y el **rango intercuartílico** para ambas columnas.
#    - ¿Qué te dice esto sobre la variabilidad de los datos? Justifica tus conclusiones con representación de graficas.

# %%
print(f"El rango de Ventas Realizadas está entre {df_rendimiento['Ventas Realizadas'].max()} y {df_rendimiento['Ventas Realizadas'].min()}")
print(f"El rango de Horas Trabajadas está entre {df_rendimiento['Horas Trabajadas'].max()} y {df_rendimiento['Horas Trabajadas'].min()}")

Q1_v = df_rendimiento['Ventas Realizadas'].quantile(0.25)
Q3_v = df_rendimiento['Ventas Realizadas'].quantile(0.75)
IQR_v = Q3_v - Q1_v

Q1_h = df_rendimiento['Horas Trabajadas'].quantile(0.25)
Q3_h = df_rendimiento['Horas Trabajadas'].quantile(0.75)
IQR_h = Q3_h - Q1_h

print(f"El IQR de Ventas Realizadas es {IQR_v}")
print(f"El IQR de Ventas Realizadas es {IQR_h}")
# Out:
# El rango de Ventas Realizadas está entre 75.0 y 25.0
# El rango de Horas Trabajadas está entre 68.52278184508938 y 23.802548959102555
# El IQR de Ventas Realizadas es 11.25
# El IQR de Ventas Realizadas es 10.06857722508515

# %%
fig, axes = plt.subplots(2, 1)

sns.boxplot(data=df_rendimiento['Ventas Realizadas'], ax=axes[0])
sns.boxplot(data=df_rendimiento['Horas Trabajadas'], ax=axes[1])
# Out:
# <Axes: ylabel='Horas Trabajadas'>

# %% [markdown]
# 5. **Cálculo de la asimetría**:
#    - Usa la función adecuada en Python para calcular la **asimetría** de los datos de **Horas Trabajadas** y **Ventas Realizadas**.
#    - Interpreta si el conjunto de datos es **simétrico**, **sesgado a la izquierda** o **sesgado a la derecha**.

# %%
print(f"La asimetría de Ventas Realizadas es {round(stats.skew(df_rendimiento['Ventas Realizadas']),2)}")
print(f"La asimetría de Horas Trabajadas es {round(stats.skew(df_rendimiento['Horas Trabajadas']),2)}")
# Out:
# La asimetría de Ventas Realizadas es 0.18
# La asimetría de Horas Trabajadas es -0.18

# %% [markdown]
# 6. **Cálculo de la curtosis**:
#    - Calcula la **curtosis** para ambos conjuntos de datos. ¿Los conjuntos tienen una curtosis positiva, negativa o son mesocúrticos?
#    - Explica qué implica esto sobre la forma de la distribución.

# %%
print(f"La asimetría de Ventas Realizadas es {kurtosis(df_rendimiento['Ventas Realizadas'])}")
print(f"La asimetría de Horas Trabajadas es {kurtosis(df_rendimiento['Horas Trabajadas'])}")

# En el caso de las ventas, es positivo, siendo ligeramente leptocúrtica, aunque por su cercanía a 0 es casi mesocúrtica.
# En el caso de las horas negativo, siendo platocúrtica, llana.
# Out:
# La asimetría de Ventas Realizadas es 0.013598589847180875
# La asimetría de Horas Trabajadas es -0.15540470774207948

# %% [markdown]
# 7. **Gráfico de dispersión**:
#    - Crea un **gráfico de dispersión** entre **Horas Trabajadas** y **Ventas Realizadas**.
#    - ¿Hay alguna correlación entre ambas variables? Explica cómo interpretar la relación entre las dos variables.

# %%
sns.scatterplot(x="Horas Trabajadas", y="Ventas Realizadas", data=df_rendimiento)
# Out:
# <Axes: xlabel='Horas Trabajadas', ylabel='Ventas Realizadas'>

# %%
# Se ve que hay una correlación positiva entre las horas trabajadas y las ventas realizadas. Cuando aumenta una, aumenta la otra también.

# %% [markdown]
# 8. **Análisis exploratorio completo**:
#    - Realiza un análisis exploratorio detallado de los datos, incluyendo todas las medidas calculadas en los ejercicios anteriores. Presenta los resultados en forma de un informe claro y visual con gráficos y tablas que resuman las características clave de los datos.

# %%
df_rendimiento
# Out:
#      ID  Horas Trabajadas  Ventas Realizadas
# 0     1         54.967142               48.0
# 1     2         48.617357               47.0
# 2     3         56.476885               55.0
# 3     4         65.230299               61.0
# 4     5         47.658466               47.0
# ..  ...               ...                ...
# 95   96         35.364851               37.0
# 96   97         52.961203               49.0
# 97   98         52.610553               53.0
# 98   99         50.051135               50.0
# 99  100         47.654129               42.0
#
# [100 rows x 3 columns]

# %%
sns.pairplot(df_rendimiento)

# %%
df_rendimiento.describe()
# Out:
#                ID  Horas Trabajadas  Ventas Realizadas
# count  100.000000        100.000000         100.000000
# mean    50.500000         48.961535          49.120000
# std     29.011492          9.081684           9.646562
# min      1.000000         23.802549          25.000000
# 25%     25.750000         43.990943          43.000000
# 50%     50.500000         48.730437          48.000000
# 75%     75.250000         54.059521          54.250000
# max    100.000000         68.522782          75.000000

# %%
df_rendimiento.dtypes
# Out:
# ID                     int64
# Horas Trabajadas     float64
# Ventas Realizadas    float64
# dtype: object

# %%
print(f"La media de ventas es {df_rendimiento['Ventas Realizadas'].mean()}")
print(f"La mediana de ventas es {df_rendimiento['Ventas Realizadas'].median()}")
# Out:
# La media de ventas es 49.12
# La mediana de ventas es 48.0

# %%
print(f"La media de horas es {df_rendimiento['Horas Trabajadas'].mean()}")
print(f"La mediana de horas es {df_rendimiento['Horas Trabajadas'].median()}")
# Out:
# La media de horas es 48.96153482605907
# La mediana de horas es 48.73043708220287

# %% [markdown]
# Las medias son representativa, por cuanto no existen muchos valores atípicos. Se ve que hay una correlación positiva entre las horas trabajadas y las ventas realizadas. Cuando aumenta una, aumenta la otra también.
